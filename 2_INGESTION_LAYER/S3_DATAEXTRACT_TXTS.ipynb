# %%
import boto3
import sys
import os
import pandas as pd
import csv
import io

# %%
s3_client =boto3.client('s3')
s3_bucket_name='hackathon2023'
s3 = boto3.resource('s3',
                    aws_access_key_id= 'AKIA3AEXDSNEGXQERCGG',
                    aws_secret_access_key='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')

# %%
my_bucket=s3.Bucket(s3_bucket_name)
print(my_bucket.objects.filter(Prefix='data'))
bucket_list = []
for file in my_bucket.objects.filter(Prefix = 'data'):
    
    file_name=file.key
    if file_name.find(".txt")!=-1:
        bucket_list.append(file.key)
length_bucket_list=print(len(bucket_list))
print(bucket_list[0:10])
# Out:
# s3.Bucket.objectsCollection(s3.Bucket(name='hackathon2023'), s3.ObjectSummary)
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Input In [3], in <module>
#       2 print(my_bucket.objects.filter(Prefix='data'))
#       3 bucket_list = []
# ----> 4 for file in my_bucket.objects.filter(Prefix = 'data'):
#       6     file_name=file.key
#       7     if file_name.find(".txt")!=-1:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\boto3\resources\collection.py:81, in ResourceCollection.__iter__(self)
#      78 limit = self._params.get('limit', None)
#      80 count = 0
# ---> 81 for page in self.pages():
#      82     for item in page:
#      83         yield item
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\boto3\resources\collection.py:171, in ResourceCollection.pages(self)
#     168 # Now that we have a page iterator or single page of results
#     169 # we start processing and yielding individual items.
#     170 count = 0
# --> 171 for page in pages:
#     172     page_items = []
#     173     for item in self._handler(self._parent, params, page):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\botocore\paginate.py:269, in PageIterator.__iter__(self)
#     267 self._inject_starting_params(current_kwargs)
#     268 while True:
# --> 269     response = self._make_request(current_kwargs)
#     270     parsed = self._extract_parsed_response(response)
#     271     if first_request:
#     272         # The first request is handled differently.  We could
#     273         # possibly have a resume/starting token that tells us where
#     274         # to index into the retrieved page.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\botocore\paginate.py:357, in PageIterator._make_request(self, current_kwargs)
#     356 def _make_request(self, current_kwargs):
# --> 357     return self._method(**current_kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\botocore\client.py:530, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     526     raise TypeError(
#     527         f"{py_operation_name}() only accepts keyword arguments."
#     528     )
#     529 # The "self" in this scope is referring to the BaseClient.
# --> 530 return self._make_api_call(operation_name, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\botocore\client.py:960, in BaseClient._make_api_call(self, operation_name, api_params)
#     958     error_code = parsed_response.get("Error", {}).get("Code")
#     959     error_class = self.exceptions.from_code(error_code)
# --> 960     raise error_class(parsed_response, operation_name)
#     961 else:
#     962     return parsed_response
#
# ClientError: An error occurred (RequestTimeTooSkewed) when calling the ListObjects operation: The difference between the request time and the current time is too large.

# %%
from io import StringIO  # Python 3.x
    
df = []   # Initializing empty list of dataframes
seq=["\t","\t","\t","\t"]
i=0
for file in bucket_list:
    obj = s3.Object(s3_bucket_name,file)
    #print(obj)
    data=obj.get()['Body'].read()
    print(data)
    df.append(pd.read_csv(io.BytesIO(data), delimiter=seq[i],header=0, low_memory=False))
    i=i+1

# %%
  # Python 3.x
    
df = []   # Initializing empty list of dataframes
seq=["\t","\t","\t",","]
i=0
for file in bucket_list:
    obj = s3.Object(s3_bucket_name,file)
    data=obj.get()['Body'].read()
    df.append(pd.read_csv(io.BytesIO(data), delimiter=seq[i],header=0, low_memory=False))
    i=i+1

# %%
df[0]

mainarr=[]
item_first=df[0].columns[0]
#print(item_first)

#print(result_1)
for i in df[0][item_first]:
    print(i)
    s1=i.split("UU-")[0].split("I")[0]
    s2=i.split("UU-")[0].split("I")[1]
    s3=i.split("UU-")[1].split("nxklh2022")[0]
    s4=i.split("nxklh2022")[1].split("-")[0]
    s5=i.split("0.1")[1].split("$$")[0].split("\R")[0]
    s6=i.split("$$")[1].split("plant")[0]
    s7_1=i.split("xi12")[1]
    j=0
    for j in range(0,100):
        if(s7_1[j].isdigit()==True):
            break;
    s7=i.split("xi12")[1].split(str(s7_1[j]))[0]
    s8=i.split("xi12")[1].split(str(s7_1[j-1]))[1]
    k=0
    for k in range(0,100):
        if(s7_1[k].isdigit()==False and s7_1[k]!=' '  and s7_1[k]!=':' and s7_1[k]!='-'):
            break;
    s9=i.split("xi12")[1].split(str(s7_1[j-1]))[1].split(str(s7_1[k]))[0]
    s10=i.split(s9)[1].split("k8")[0]
    s11=i.split(s9)[1].split("k8")[1].split("bHM")[0]
    s12=i.split(s9)[1].split("k8")[1].split("bHM")[1].split("--")[0]
    s13=i.split(s9)[1].split("k8")[1].split("bHM")[1].split("--")[1].split("P011")[0]
    s14=i.split(s9)[1].split("k8")[1].split("bHM")[1].split("--")[1].split("P011")[1].split("MD")[0]
    s15=i.split(s9)[1].split("k8")[1].split("bHM")[1].split("--")[1].split("P011")[1].split("MD")[1]
    arr=(s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13,s14,s15)
    print(arr)
    mainarr.append(arr)
    
    
    #C021I<ID>UU-<Description>nxklh2022<Modality>-kls0.1<Revision>\\R$$<BaseUOM>plantxi12<Batch_Management>2022-12-08 11:01:15<SerialNumber_Profile>k8<ShelfLife>bHM<ShelfLife_Date>--<MSD>P011<Item_Category>MD<MSLDetails>

#print(mainarr)

# %%
df[1]
df[1].to_csv('../LAKEHOUSE_SILVER_LAYER/production.csv',index=False)
